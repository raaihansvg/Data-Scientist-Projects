# %%
import pandas as pd

path = "/content/drive/MyDrive/DatasetStudent/student_academic_performance_1M.csv"
data = pd.read_csv(path)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
data.columns
# Out:
# Index(['math_score', 'science_score', 'english_score', 'history_score',
#        'computer_score', 'attendance_rate', 'assignment_avg', 'quiz_avg',
#        'project_score', 'previous_gpa', 'study_hours_daily', 'revision_hours',
#        'age', 'gender', 'urban_flag', 'family_size', 'parent_education',
#        'family_income', 'sleep_hours', 'physical_activity', 'screen_time',
#        'junk_food_freq', 'bmi', 'illness_days', 'mental_stress',
#        'sleep_quality', 'internet_access', 'private_tuition', 'tuition_hours',
#        'study_room', 'parent_involvement', 'scholarship_flag',
#        'part_time_job_hours', 'financial_stress', 'online_course_hours',
#        'lms_login_frequency', 'coding_practice_hours', 'ai_tool_usage',
#        'digital_literacy', 'video_watch_hours', 'forum_participation',
#        'device_availability', 'final_gpa', 'standardized_exam_score',
#        'improvement_next_term', 'dropout_risk_score', 'learning_efficiency',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   math_score               1000000 non-null  float64
#  1   science_score            1000000 non-null  float64
#  2   english_score            1000000 non-null  float64
#  3   history_score            1000000 non-null  float64
#  4   computer_score           1000000 non-null  float64
#  5   attendance_rate          1000000 non-null  float64
#  6   assignment_avg           1000000 non-null  float64
#  7   quiz_avg                 1000000 non-null  float64
#  8   project_score            1000000 non-null  float64
#  9   previous_gpa             1000000 non-null  float64
#  10  study_hours_daily        1000000 non-null  float64
#  11  revision_hours           1000000 non-null  float64
#  12  age                      1000000 non-null  int64
# ...

# %%
data.describe()
# Out:
#            math_score   science_score   english_score   history_score  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        64.990677       68.004199       69.995202       66.009075
# std         14.407658       13.592084       11.395360       12.038289
# min        -12.256755        1.516067       12.479786        8.838778
# 25%         55.282638       58.848191       62.305380       57.894759
# 50%         64.994800       67.996100       69.984695       66.006192
# 75%         74.703280       77.167130       77.691767       74.109052
# max        133.154240      130.585130      126.147410      124.252830
#
#        computer_score  attendance_rate  assignment_avg        quiz_avg  \
# count  1000000.000000   1000000.000000  1000000.000000  1000000.000000
# mean        72.000415         0.749588       60.007929       61.967112
# std         11.656679         0.110521       18.029055       15.612250
# ...

# %%
data.shape
# Out:
# (1000000, 52)

# %%
data.isnull().sum()
# Out:
# math_score                 0
# science_score              0
# english_score              0
# history_score              0
# computer_score             0
# attendance_rate            0
# assignment_avg             0
# quiz_avg                   0
# project_score              0
# previous_gpa               0
# study_hours_daily          0
# revision_hours             0
# age                        0
# gender                     0
# urban_flag                 0
# family_size                0
# parent_education           0
# family_income              0
# sleep_hours                0
# physical_activity          0
# screen_time                0
# junk_food_freq             0
# bmi                        0
# illness_days               0
# mental_stress              0
# sleep_quality              0
# internet_access            0
# private_tuition            0
# tuition_hours              0
# study_room                 0
# parent_involvement         0
# scholarship_flag           0
# ...

# %% [markdown]
# There are no missing values in this data

# %% [markdown]
# **Data Visualization**

# %%
data.columns
# Out:
# Index(['math_score', 'science_score', 'english_score', 'history_score',
#        'computer_score', 'attendance_rate', 'assignment_avg', 'quiz_avg',
#        'project_score', 'previous_gpa', 'study_hours_daily', 'revision_hours',
#        'age', 'gender', 'urban_flag', 'family_size', 'parent_education',
#        'family_income', 'sleep_hours', 'physical_activity', 'screen_time',
#        'junk_food_freq', 'bmi', 'illness_days', 'mental_stress',
#        'sleep_quality', 'internet_access', 'private_tuition', 'tuition_hours',
#        'study_room', 'parent_involvement', 'scholarship_flag',
#        'part_time_job_hours', 'financial_stress', 'online_course_hours',
#        'lms_login_frequency', 'coding_practice_hours', 'ai_tool_usage',
#        'digital_literacy', 'video_watch_hours', 'forum_participation',
#        'device_availability', 'final_gpa', 'standardized_exam_score',
#        'improvement_next_term', 'dropout_risk_score', 'learning_efficiency',
# ...

# %%
data['privat']

# %% [markdown]
# *1. Academic Features*

# %%
import seaborn as sns
import matplotlib.pyplot as plt

academic_cols = [
    "math_score", "science_score", "english_score",
    "history_score", "computer_score","attendance_rate",
    "assignment_avg", "quiz_avg", "project_score", "previous_gpa","study_hours_daily",
    "revision_hours","private_tuition","tuition_hours","study_room","scholarship_flag",
    "digital_literacy",
]

data[academic_cols].hist(figsize=(18, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# *2. Mental & Health Features*

# %%
health_cols = [
    "sleep_hours","physical_activity","screen_time","illness_days",
    "mental_stress","sleep_quality","stress_index"
]

data[health_cols].hist(figsize=(16, 8), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# *3. Family & Finance Features*

# %%
family_cols = [
    "family_size", "parent_education","family_income","parent_involvement",
    "part_time_job_hours","financial_stress","device_availability"
]

data[family_cols].hist(figsize=(16, 8), bins=30)
plt.tight_layout()
plt.show()

# %%
academic = data[academic_cols + ["final_gpa"]].corr()

plt.figure(figsize=(12,10))
sns.heatmap(
    academic,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Academic Feature Correlation Heatmap")
plt.show()

# %%
mental_and_health = data[health_cols + ["final_gpa"]].corr()

plt.figure(figsize=(12,10))
sns.heatmap(
    mental_and_health,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Mental and Health Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# *Kesimpulan korelasi negatif(Non Target)*
#
# 1. Sleep Hours -> Ilness Days : Jika jam tidur terjaga maka kemungkinan untuk terkena penyakit akan turun
# 2. Sleep Hours -> Stress Index : Jika jam tidur terjaga maka kemungkinan stress juga akan menurun
# 3. Physical Activity -> Ilness Days : Jika sering melakukan kegiatan fisik(olahraga dll) maka kemungkinan terkena penyakit akan menurun
# 4. Physical Activity -> Stress Index : Jika sering melakukan kegiatan fisik
# (olahraga dll) maka kemungkinan stress juga akan menurun
# 5. Ilness Days -> Sleep Quality : Jika kualitas tidur terjaga maka kemungkinan untuk terkana penyakit juga akan menurun
# 6. Sleep Quality -> Stress Index : Jika kualitas tidur terjaga maka kemungkinan stress juga akan menurun
# ________________________________________________________________________________
# *Kesimpulan korelasi negatif(Target)*
# 1. Screen Time -> Final Gpa : Jika mengontrol aktivitas penggunaan gadget dll maka untuk mendapatkan gpa yang lebih baik akan meningkat
# 2. Mental Stress -> Final Gpa : Jika sesorang tidak mengalami stress mental maka untuk kemungkinan mendapatkan gpa yang bagus akan meningkat
# 3. Stress Index -> Final Gpa : Jika sesorang tidak mengalami stress maka kemungkinan untuk mendapatkan gpa yang bagus akan meningkat

# %%
family = data[family_cols + ["final_gpa"]].corr()

plt.figure(figsize=(12,10))
sns.heatmap(
    family,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Family and Finance Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# *Kesimpulan korelasi negatif(Non Target)*
#
# 1. Parent Involvement -> Financial Stress : Jika keterlibatan orang tua dalam faktor ekonomi kepada anak nya terjaga maka kemungkinan anak untuk stress financial juga akan menurun

# %%
selected_cols = family_cols + health_cols + academic_cols

unused_cols = list(set(data.columns) - set(selected_cols))
unused_cols = [col for col in data.columns if col not in selected_cols]

unused_cols
# Out:
# ['age',
#  'gender',
#  'urban_flag',
#  'junk_food_freq',
#  'bmi',
#  'internet_access',
#  'online_course_hours',
#  'lms_login_frequency',
#  'coding_practice_hours',
#  'ai_tool_usage',
#  'video_watch_hours',
#  'forum_participation',
#  'final_gpa',
#  'standardized_exam_score',
#  'improvement_next_term',
#  'dropout_risk_score',
#  'learning_efficiency',
#  'pass_fail',
#  'honors_flag',
#  'at_risk_flag',
#  'top_performer_flag']

# %%
unused = unused_cols.remove('final_gpa')
unused = data[unused_cols + ["final_gpa"]].corr()

plt.figure(figsize=(12,10))
sns.heatmap(
    unused,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)
plt.title("Unused Feature Correlation Heatmap")
plt.show()
